# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Built-in library
import itertools
import re
import json
import typing as tp

# pandas settings
pd.options.display.max_rows = 1_000
pd.options.display.max_columns = 1_000
pd.options.display.max_colwidth = 1_000

# Black code formatter (Optional)
# %reload_ext lab_black

# %%
name = bio_data_2.gen_email
print(name)

# %%
# def gen_email(self):
#     # name_3 = firstname_gt.lower().replace(" ", "")
#     # # Remove spaces in the generated name

#     # domain = random.choice(["@yahoo.com", "@gmail.com"])
#     email = f"{first_name_gt}{domain}"
#     return email

# %%
from faker import Faker
import csv
import random

fake = Faker()


def generate_random_address():
    states = {
        "Lagos": {
            "Agege": {
                "street_names": [
                    "Oko-Oba Road",
                    "Ipaja Road",
                    "Capitol Road",
                    "Ogba Road",
                    "Dopemu Road",
                    "Abule Egba Road",
                ],
                "cities": ["Agege", "Dopemu", "Ipaja", "Ogba"],
            },
            "Ikeja": {
                "street_names": [
                    "Allen Avenue",
                    "Opebi Road",
                    "Obafemi Awolowo Way",
                    "Adeniyi Jones Avenue",
                    "Awolowo Road",
                    "Toyin Street",
                ],
                "cities": ["Ikeja", "Opebi", "Allen", "Maryland"],
            },
            "Surulere": {
                "street_names": [
                    "Adeniran Ogunsanya Street",
                    "Bode Thomas Street",
                    "Itire Road",
                    "Ogunlana Drive",
                    "Ishaga Road",
                    "Ojuelegba Road",
                ],
                "cities": ["Surulere", "Ojuelegba", "Aguda", "Ijesha"],
            },
            "Epe": {
                "street_names": [
                    "Marina Road",
                    "Aiyetoro Road",
                    "Adewale Crescent",
                    "Oke Osho Road",
                    "Epe-Ijebu Ode Road",
                    "Itoikin Road",
                ],
                "cities": ["Epe", "Itoikin", "Iwerekun", "Aiyetoro"],
            },
        },
        "Ogun": {
            "Abeokuta": {
                "street_names": [
                    "Lalubu Road",
                    "Olusegun Obasanjo Way",
                    "Moshood Abiola Way",
                    "Isabo Road",
                    "Panseke-Adigbe Road",
                    "Kuto Road",
                ],
                "cities": ["Abeokuta", "Sokori", "Panseke", "Isabo"],
            },
            "Ijebu-Ode": {
                "street_names": [
                    "Odo Eri Road",
                    "Ejinrin Road",
                    "Ogbere Road",
                    "Ijari Road",
                    "Ojowo Road",
                    "Ikangba Road",
                ],
                "cities": ["Ijebu-Ode", "Ogbere", "Ejinrin", "Ojowo"],
            },
        },
        "Kano": {
            "Kano Municipal": {
                "street_names": [
                    "Bello Road",
                    "Ibrahim Taiwo Road",
                    "Kofar Nassarawa Road",
                    "Bank Road",
                    "Kofar Wambai Road",
                    "Sarkin Yaki Road",
                ],
                "cities": ["Kano", "Dala", "Nasarawa", "Gwale"],
            },
            "Fagge": {
                "street_names": [
                    "Sabo Bakin Zuwo Road",
                    "Janguza Road",
                    "Yankaba Road",
                    "Daurawa Road",
                    "Yakasai Road",
                    "Babban Daki Road",
                ],
                "cities": ["Fagge", "Yankaba", "Bakin Zuwo", "Daurawa"],
            },
            "Gwale": {
                "street_names": [
                    "Gidan Murtala Road",
                    "Rijiyar Zaki Road",
                    "Filing Dabo Road",
                    "Giginyu Road",
                    "Wudil Road",
                    "Rijiyar Lemo Road",
                ],
                "cities": ["Gwale", "Rijiyar Zaki", "Giginyu", "Fagge"],
            },
            "Nassarawa": {
                "street_names": [
                    "Bataiya Road",
                    "Katsina Road",
                    "Rijiyar Zaki Road",
                    "Barnawa Road",
                    "Yalwa Road",
                    "Gwammaja Road",
                ],
                "cities": ["Nassarawa", "Kofar Wambai", "Rijiyar Lemo", "Gidan Dabo"],
            },
        },
        "Rivers": {
            "Port Harcourt": {
                "street_names": [
                    "Abacha Road",
                    "Aggrey Road",
                    "Stadium Road",
                    "Aba Road",
                    "Trans-Amadi Road",
                    "Rumuola Road",
                ],
                "cities": ["Port Harcourt", "D-line", "Trans-Amadi", "Rumuola"],
            },
            "Obio/Akpor": {
                "street_names": [
                    "Nkpolu Road",
                    "Elelenwo Road",
                    "Rumuokwurusi Road",
                    "Slaughter Road",
                    "Eneka Road",
                    "Choba Road",
                ],
                "cities": ["Rumuokwurusi", "Rumuepirikom", "Rumukwurusi", "Rumuokoro"],
            },
            "Ikwerre": {
                "street_names": [
                    "Wimpey Road",
                    "Nkpolu Road",
                    "Rumuigbo Road",
                    "Igwuruta Road",
                    "Ozuoba Road",
                    "Isiokpo Road",
                ],
                "cities": ["Rumuigbo", "Nkpolu", "Rumueme", "Ozuoba"],
            },
            "Eleme": {
                "street_names": [
                    "Ogale Road",
                    "Ebubu Road",
                    "Onne Road",
                    "Aleto Road",
                    "Agbonchia Road",
                    "Oyigbo Road",
                ],
                "cities": ["Onne", "Ebubu", "Aleto", "Eteo"],
            },
        },
        "Enugu": {
            "Enugu East": {
                "street_names": [
                    "Independence Layout",
                    "Rangers Avenue",
                    "Abakpa Nike Road",
                    "Ogui Road",
                    "New Haven Road",
                    "Trans-Ekulu Road",
                ],
                "cities": [
                    "Enugu",
                    "Independence Layout",
                    "Trans-Ekulu",
                    "Abakpa Nike",
                ],
            },
            "Nsukka": {
                "street_names": [
                    "University Road",
                    "Alor Uno Road",
                    "Ibagwa Road",
                    "Odenigwe Road",
                    "Owerre Ezukala Road",
                    "Akpugo Road",
                ],
                "cities": ["Nsukka", "Odenigwe", "Ibagwa", "Owerre Ezukala"],
            },
            "Enugu North": {
                "street_names": [
                    "Zik Avenue",
                    "Ogui Road",
                    "Rangers Avenue",
                    "Coal Camp Road",
                    "Uwani Road",
                    "Golf Estate Road",
                ],
                "cities": ["Enugu", "Uwani", "Rangers", "New Haven"],
            },
            "Enugu South": {
                "street_names": [
                    "Akpugo Road",
                    "Udi Road",
                    "Awgu Road",
                    "Agbani Road",
                    "Eke Road",
                    "Opi Road",
                ],
                "cities": ["Enugu", "Agbani", "Akpugo", "Udi"],
            },
        },
        "Delta": {
            "Warri": {
                "street_names": [
                    "Effurun-Sapele Road",
                    "Ajamimogha Road",
                    "Airport Road",
                    "Okumagba Avenue",
                    "Jakpa Road",
                    "Deco Road",
                ],
                "cities": ["Warri", "Effurun", "Ekpan", "Ugbuwangue"],
            },
            "Ughelli": {
                "street_names": [
                    "Ughelli-Patani Road",
                    "Market Road",
                    "Isoko Road",
                    "Agbarha Road",
                    "Oteri Road",
                    "Iwhrekan Road",
                ],
                "cities": ["Ughelli", "Oteri", "Agbarha-Otor", "Ovwian"],
            },
            "Asaba": {
                "street_names": [
                    "Nnebisi Road",
                    "Anwai Road",
                    "Okpanam Road",
                    "Dennis Osadebe Way",
                    "Summit Road",
                    "Mariam Babangida Way",
                ],
                "cities": ["Asaba", "Okpanam", "Illah", "Ibusa"],
            },
            "Sapele": {
                "street_names": [
                    "Warri-Sapele Road",
                    "New Ogorode Road",
                    "Amukpe Road",
                    "Market Road",
                    "Deco Road",
                    "Okirigbobor Road",
                ],
                "cities": ["Sapele", "Amukpe", "Elume", "Ogorode"],
            },
        },
    }

    state = random.choice(list(states.keys()))
    lgas = states[state]
    city = random.choice(list(lgas.keys()))
    lga = random.choice(list(lgas))  # Convert lgas.keys() to list

    # Get street names for the selected city
    street_names = lgas[city]["street_names"]
    street_name = random.choice(street_names)

    # Generate a random street number (between 1 and 100)
    street_number = random.randint(1, 100)

    # Use the selected street name, city, LGA, and state to create an address
    address = f"{street_number} {street_name}STR., {city}, {lga} LGA, {state} State"
    return address


class bio:
    def __init__(self) -> None:
        pass

    def generate_name(self):
        first_name = [
            "Abiola",
            "Adamma",
            "Adeola",
            "Ahmed",
            "Aisha",
            "Amara",
            "Anayo",
            "Anita",
            "Ayodele",
            "Bisi",
            "Chiamaka",
            "Chibuzo",
            "Chidinma",
            "Chioma",
            "Chukwudi",
            "Damilola",
            "Ebuka",
            "Emeka",
            "Ezinne",
            "Folarin",
            "Funke",
            "Ganiyu",
            "Halima",
            "Hassan",
            "Ifeanyi",
            "Ikechukwu",
            "Immanuel",
            "Isaiah",
            "Jide",
            "Kafayat",
            "Kemi",
            "Khadija",
            "Lola",
            "Musa",
            "Nkechi",
            "Nnamdi",
            "Nneka",
            "Obinna",
            "Ogechi",
            "Olajide",
            "Olufemi",
            "Oluwakemi",
            "Omolara",
            "Onyeka",
            "Osagie",
            "Patience",
            "Rasheed",
            "Rukayat",
            "Sadiq",
            "Sandra",
            "Seyi",
            "Suleiman",
            "Taiwo",
            "Temitope",
            "Tunde",
            "Uche",
            "Umar",
            "Yakubu",
            "Yusuf",
            "Zainab",
            "Abiola",
            "Adamma",
            "Adeola",
            "Ahmed",
            "Aisha",
            "Amara",
            "Anayo",
            "Anita",
            "Ayodele",
            "Bisi",
            "Chiamaka",
            "Chibuzo",
            "Chidinma",
            "Chioma",
            "Chukwudi",
            "Damilola",
            "Ebuka",
            "Emeka",
            "Olajide",
            "Olufemi",
            "Oluwakemi",
            "Omolara",
            "Ahmed",
            "Vande",
            "Obinna",
            "Dayo",
            "Obinna",
            "Ada",
            "Ahmed",
            "Aisha",
            "Amaka",
            "Bola",
            "Chidi",
            "Chioma",
            "Chukwudi",
            "Daniel",
            "Ebere",
            "Emeka",
            "Ese",
            "Femi",
            "Funke",
            "Gabriel",
            "Halima",
            "Hassan",
            "Ifeanyi",

            "Ibrahim",
            "Idris",
            "Igbinedion",
            "Iheanacho",
            "Ikenwa",
            "Iroegbu",
            "Ismail",
            "Jibril",
            "Johnson",
            "Kuti",
            "Lawal",
            "Maduka",
            "Mahmud",
            "Mohammed",
            "Musa",
            "Nwachukwu",
            "Nwosu",
            "Obi",
            "Odeyemi",
            "Odumegwu",
            "Ogundipe",
            "Oguntade",
            "Okeke",
            "Okonkwo",
            "Oladipo",
            "Olajide",
            "Adekunle",
            "Onwuka",
            "Osagie",
            "Okafor",
            "Adebayo",
            "Adegoke",
            "Eze",
            "Ogundele",
            "Okoro",
            "Nwosu",
            "Okafor",
            "Egwu",
            "Oladipo",
            "Okeke",
            "Nnamdi",
            "Ibe",
            "Adewale",
            "Abdul",
            "Okonkwo",
            "Aliyu",
            "Onyeka",
            "Okoli",
            "Chukwu",
            "Ahmed",
            "Eze",
            "Adamu",
            "Akintola",
            "Ogunbiyi",
            "Iwu",
            "Adeyemi",
            "Obi",
            "Musa",
            "Nwachukwu",
            "Usman",
            "Ude",
            "Lawal",
            "Okafor",
            "Mohammed",
            "Eze",
            "Ibrahim",
            "Anyanwu",
            "Olamide",
            "Ogundele",
            "Akinwale",
            "Balogun",
            "Okonkwo",
            "Onyeka",
            "Sani",
            "Eze",
            "Mohammed",
            "Okafor",
            "Ibrahim",
            "Nwachukwu",
            "Ahmed",
            "Nwosu",
            "Hassan",
            "Onuoha",
            "Lawal",
            "Eze",
            "Suleiman",
            "Okoye",
            "Eze",
            "Nwachukwu",
            "Okafor",
            "Nwosu",
            "Abdullahi",
        ]

        firstname = random.choice(first_name)
        lastname = random.choice(last_name)

        name = f"{firstname} {lastname}"

        return name

    def generate_email(self):
        # name = self.generate_name()
        name_2 = name.lower().replace(" ", "")
        # Remove spaces in the generated name

        domain = random.choice(["@yahoo.com", "@gmail.com"])
        email = f"{name_2}{domain}"
        return email


class bionum:
    def __init__(self) -> None:
        pass

    def generate_names(self):
        first_name = [
            "Abiola",
            "Adamma",
            "Adeola",
            "Ahmed",
            "Aisha",
            "Amara",
            "Anayo",
            "Anita",
            "Ayodele",
            "Bisi",
            "Chiamaka",
            "Chibuzo",
            "Chidinma",
            "Chioma",
            "Chukwudi",
            "Damilola",
            "Ebuka",
            "Emeka",
            "Ezinne",
            "Folarin",
            "Funke",
            "Ganiyu",
            "Halima",
            "Hassan",
            "Ifeanyi",
            "Ikechukwu",
            "Immanuel",
            "Isaiah",
            "Jide",
            "Kafayat",
            "Kemi",
            "Khadija",
            "Lola",
            "Musa",
            "Nkechi",
            "Nnamdi",
            "Nneka",
            "Obinna",
            "Ogechi",
            "Olajide",
            "Olufemi",
            "Oluwakemi",
            "Omolara",
            "Onyeka",
            "Osagie",
            "Patience",
            "Rasheed",
            "Rukayat",
            "Sadiq",
            "Sandra",
            "Seyi",
            "Suleiman",
            "Taiwo",
            "Temitope",
            "Tunde",
            "Uche",

            "Jibril",
            "Johnson",
            "Kuti",
            "Lawal",
            "Madu",
            "Mohammed",
            "Mustapha",
            "Nwachukwu",
            "Obi",
            "Obioma",
            "Odeyemi",
            "Ogbu",
            "Ogunjimi",
            "Ogunleye",
            "Ogunmola",
            "Ogunwale",
            "Okonkwo",
            "Okorie",
            "Okosun",
            "Okoye",
            "Olabode",
            "Oladipo",
            "Olagunju",
            "Olamide",
            "Olaniyi",
            "Olawale",
            "Olumide",
            "Olusola",
            "Omololu",
            "Onuoha",
            "Onyia",
            "Onyishi",
            "Oyebanji",
            "Oyedepo",
            "Ezeani",
            "Ibrahim",
            "Idris",
            "Igbinedion",
            "Ihejirika",
            "Ijaiya",
            "Ikenwa",
            "Iwu",
            "Jibril",
            "Johnson",
            "Kuti",
            "Lawal",
            "Madu",
            "Mohammed",
            "Mustapha",
            "Nwachukwu",
            "Obi",
            "Obioma",
            "Odeyemi",
            "Ogbu",
            "Ogunjimi",
            "Kolapo",
            "Lawal",
            "Elijaj",
            "Julius",
            "Ehinmoro",
            "Jude",
            "Abubakar",
            "Adewale",
            "Afolabi",
            "Ajayi",
            "Akintola",
            "Alabi",
            "Aliyu",
            "Aminu",
            "Azikiwe",
            "Babatunde",
            "Balogun",
            "Bello",
            "Chukwu",
            "Dauda",
            "Egbu",
            "Eke",
            "Ekwueme",
            "Emeka",
            "Fashola",
            "Gbenga",
            "Ibrahim",
            "Idris",
            "Igbinedion",
            "Iheanacho",
            "Ikenwa",
            "Iroegbu",
            "Ismail",
            "Jibril",
            "Johnson",
            "Kuti",
            "Lawal",
            "Maduka",
            "Mahmud",
            "Mohammed",
            "Musa",
            "Nwachukwu",
            "Nwosu",
            "Obi",
            "Odeyemi",
            "Odumegwu",
            "Ogundipe",
            "Oguntade",
            "Okeke",
            "Okonkwo",
            "Oladipo",
            "Olajide",
            "Adekunle",
            "Onwuka",
            "Osagie",
            "Okafor",
            "Adebayo",
            "Adegoke",
            "Eze",
            "Ogundele",
            "Okoro",
            "Nwosu",
            "Okafor",
            "Egwu",
            "Oladipo",
            "Okeke",
            "Nnamdi",
            "Ibe",
            "Adewale",
            "Abdul",
            "Okonkwo",
            "Aliyu",
            "Onyeka",
            "Okoli",
            "Chukwu",
            "Ahmed",
            "Eze",
            "Adamu",
            "Akintola",
            "Ogunbiyi",
            "Iwu",
            "Adeyemi",
            "Obi",
            "Musa",
            "Nwachukwu",
            "Usman",
            "Ude",
            "Lawal",
            "Okafor",
            "Mohammed",
            "Eze",
            "Ibrahim",
            "Anyanwu",
            "Olamide",
            "Ogundele",
            "Akinwale",
            "Balogun",
            "Okonkwo",
            "Onyeka",
            "Sani",
            "Eze",
            "Mohammed",
            "Okafor",
            "Ibrahim",
            "Nwachukwu",
            "Ahmed",
            "Nwosu",
            "Hassan",
            "Onuoha",
            "Lawal",
            "Eze",
            "Suleiman",
            "Okoye",
            "Eze",
            "Nwachukwu",
            "Okafor",
            "Nwosu",
            "Abdullahi",
        ]

        firstname = random.choice(first_name)
        lastname = random.choice(last_name)

        names = f"{firstname} {lastname}"

        return names

    def generate_emails(self):
        names = self.generate_names()
        firstname_3 = names.lower().replace(" ", "")
        # Remove spaces in the generated name

        domain = random.choice(["@yahoo.com", "@gmail.com"])
        email = f"{firstname_3}{domain}"
        return email


bio_data_2 = bionum()
bio_data = bio()


# Open a CSV file for writing
with open(
    "C:/Users/Todays Soutions/Documents/Data_Science/DATA/loannewdata.csv",
    "w",
    newline="",
) as file:
    writer = csv.writer(file)
    # Write header row

    writer.writerow(
        [
            "Name",
            "Phone Number",
            "Email Address",
            "Date of Birth",
            "Address",
            "National Identity Number",
            "Employment",
            "Income per month",
            "Loan Type",
            "Applicant's Job Role Sector",
            "Repayment Type",
            "Credit Score",
            "Collateral Type",
            "Collateral Value",
            "Guarantor's Name",
            "Guarantor's Phone Number",
            "Guarantor's Email",
            "Guarantor's Date of Birth",
            "Guarantor's Address",
            "Guarantor's Social Security Number",
            "Guarantor's Relationship",
            "Guarantor's Employment",
            "Guarantor's Other sources of income",
            "Guarantor's Income per month",
            "Loan Amount",
            "Loan Default",
        ]
    )

    # Generate 200,000 rows of data
    for _ in range(500):
        name = bio_data.generate_name()
        phone_number = (
            fake.random_element(["080", "070", "081", "090", "091"])
            + "-"
            + fake.numerify("####")
            + "-"
            + fake.numerify("####")
        )

        email = bio_data.generate_email()
        date_of_birth = fake.date_of_birth()
        address = generate_random_address()
        national_indentity_number = fake.random_number(digits=11)
        employment = fake.random_element(
            ["FullTime", "PartTime", "Self-Employed", "Contract"]
        )
        income_per_month = fake.random_int(min=50000, max=500000)
        loan_type = fake.random_element(
            ["Housing Loan", "Student Loan", "Agricultural Loan", "Business Loan"]
        )
        applicants_job_role_sector = fake.random_element(
            [
                "Accountant (Accounting and Finance)",
                "Financial Analyst (Accounting and Finance)",
                "Auditor (Accounting and Finance)",
                "Tax Specialist (Accounting and Finance)",
                "Financial Manager (Accounting and Finance)",
                "Marketing Manager (Marketing and Advertising)",
                "Digital Marketer (Marketing and Advertising)",
                "Brand Manager (Marketing and Advertising)",
                "Advertising Executive (Marketing and Advertising)",
                "Market Research Analyst (Marketing and Advertising)",
                "Software Developer (Information Technology",
                "Network Administrator (Information Technology)",
                "Data Scientist (Information Technology)",
                "Cybersecurity Analyst (Information Technology)",
                "IT Project Manager (Information Technology)",
                "Doctor (Healthcare)",
                "Nurse (Healthcare)",
                "Medical Assistant (Healthcare)",
                "Pharmacist (Healthcare)",
                "Physical Therapist (Healthcare)",
                "Teacher (Education and Training)",
                "Professor (Education and Training)",
                "Instructional Designer (Education and Training)",
                "Training Specialist (Education and Training)",
                "Education Consultant (Education and Training)",
                "Sales Representative (Sales and Customer Service)",
                "Account Manager (Sales and Customer Service)",
                "Customer Service Representative (Sales and Customer Service)",
                "Sales Manager (Sales and Customer Service)",
                "Retail Associate (Sales and Customer Service)",
                "Mechanical Engineer (Engineering)",
                "Electrical Engineer (Engineering)",
                "Civil Engineer (Engineering)",
                "Quality Control Inspector (Engineering)",
                "HR Manager (Human Resources)",
                "Recruitment Specialist (Human Resources)",
                "Training and Development Manager (Human Resources)",
                "Compensation and Benefits Analyst (Human Resources)",
                "Project Manager (Project Management)",
                "Agile Coach (Project Management)",
                "Scrum Master (Project Management)",
                "Program Manager (Project Management)",
                "Operations Manager (Operations and Logistics)",
                "Supply Chain Analyst (Operations and Logistics)",
                "Warehouse Supervisor (Operations and Logistics)",
                "Logistics Coordinator (Operations and Logistics)",
                "Lawyer (Legal)",
                "Paralegal (Legal)",
                "Judge (Legal)",
                "Legal Counsel (Legal)",
            ]
        )

        repayment_type = fake.random_element(
            [
                "Interest only",
                "Principal & Interest",
                "Capitalized Interest",
                "Housing Loan",
                "Others",
            ]
        )

        credit_score = fake.random_number(digits=3)
        collateral_type = fake.random_element(["Business Equipment", "Real Estate"])
        collateral_value = fake.random_int(min=100000, max=10000000)
        guarantor_name = bio_data_2.generate_names()
        guarantor_phone_number = (
            fake.random_element(["080", "070", "081", "090"])
            + "-"
            + fake.numerify("####")
            + "-"
            + fake.numerify("####")
        )

        guarantor_email = bio_data_2.generate_emails()
        guarantor_dob = fake.date_of_birth()
        guarantor_address = generate_random_address()
        guarantor_ssn = fake.ssn()
        guarantor_relationship = fake.random_element(
            ["Parent", "Sister", "Brother", "Spouse", "Friend", "Employer"]
        )
        guarantor_employment = fake.random_element(
            ["FullTime", "PartTime", "Retiree", "Contract", "Business Owner"]
        )

        guarantor_other_sources_income = fake.random_element(
            [
                "Rental Income",
                "Investment Income",
                "Freelancing",
                "Business Profits",
                "Royalties",
                "Agriculture and Farming",
                "Rental of Assets",
            ]
        )

        guarantor_income_per_month = fake.random_int(min=200000, max=1000000)
        loan_amount = fake.random_int(min=10000, max=1000000)

        loan_default = fake.random_element(["Yes", "No"])

        # Write the data to the CSV file
        writer.writerow(
            [
                name,
                phone_number,
                email,
                date_of_birth,
                address,
                national_indentity_number,
                employment,
                income_per_month,
                loan_type,
                applicants_job_role_sector,
                repayment_type,
                credit_score,
                collateral_type,
                collateral_value,
                guarantor_name,
                guarantor_phone_number,
                guarantor_email,
                guarantor_dob,
                guarantor_address,
                guarantor_ssn,
                guarantor_relationship,
                guarantor_employment,
                guarantor_other_sources_income,
                guarantor_income_per_month,
                loan_amount,
                loan_default,
            ]
        )

# %%
df = pd.read_csv("C:/Users/Todays Soutions/Documents/Data_Science/DATA/loannewdata.csv")
df.head()
# Out:
#                Name   Phone Number              Email Address Date of Birth  \
# 0  Zainab Nwachukwu  080-9482-4624  zainabnwachukwu@gmail.com    1961-06-09
# 1        Uche Usman  080-6519-5748        ucheusman@gmail.com    1963-06-05
# 2    Amarachi Okeke  081-3764-4054    amarachiokeke@gmail.com    1982-05-07
# 3     Ifeanyi Okoli  091-3468-6744     ifeanyiokoli@gmail.com    1977-12-18
# 4       Taiwo Alabi  091-4116-4284       taiwoalabi@yahoo.com    1914-12-13
#
#                                                                Address  \
# 0            24 Obafemi Awolowo WaySTR., Ikeja, Ikeja LGA, Lagos State
# 1                       23 Opebi RoadSTR., Ikeja, Epe LGA, Lagos State
# 2               8 Bank RoadSTR., Kano Municipal, Gwale LGA, Kano State
# 3  63 Rumuola RoadSTR., Port Harcourt, Port Harcourt LGA, Rivers State
# 4       29 Barnawa RoadSTR., Nassarawa, Kano Municipal LGA, Kano State
#
#    National Identity Number     Employment  Income per month  \
# ...

# %%
random_address = generate_random_address()
print(random_address)

# %%
from faker import Faker
import csv
import random

fake = Faker()


def generate_random_address():
    states = {
        "Lagos": {
            "Agege": {
                "street_names": [
                    "Oko-Oba Road",
                    "Ipaja Road",
                    "Capitol Road",
                    "Ogba Road",
                    "Dopemu Road",
                    "Abule Egba Road",
                ],
                "cities": ["Agege", "Dopemu", "Ipaja", "Ogba"],
            },
            "Ikeja": {
                "street_names": [
                    "Allen Avenue",
                    "Opebi Road",
                    "Obafemi Awolowo Way",
                    "Adeniyi Jones Avenue",
                    "Awolowo Road",
                    "Toyin Street",
                ],
                "cities": ["Ikeja", "Opebi", "Allen", "Maryland"],
            },
            "Surulere": {
                "street_names": [
                    "Adeniran Ogunsanya Street",
                    "Bode Thomas Street",
                    "Itire Road",
                    "Ogunlana Drive",
                    "Ishaga Road",
                    "Ojuelegba Road",
                ],
                "cities": ["Surulere", "Ojuelegba", "Aguda", "Ijesha"],
            },
            "Epe": {
                "street_names": [
                    "Marina Road",
                    "Aiyetoro Road",
                    "Adewale Crescent",
                    "Oke Osho Road",
                    "Epe-Ijebu Ode Road",
                    "Itoikin Road",
                ],
                "cities": ["Epe", "Itoikin", "Iwerekun", "Aiyetoro"],
            },
        },
        "Ogun": {
            "Abeokuta": {
                "street_names": [
                    "Lalubu Road",
                    "Olusegun Obasanjo Way",
                    "Moshood Abiola Way",
                    "Isabo Road",
                    "Panseke-Adigbe Road",
                    "Kuto Road",
                ],
                "cities": ["Abeokuta", "Sokori", "Panseke", "Isabo"],
            },
            "Ijebu-Ode": {
                "street_names": [
                    "Odo Eri Road",
                    "Ejinrin Road",
                    "Ogbere Road",
                    "Ijari Road",
                    "Ojowo Road",
                    "Ikangba Road",
                ],
                "cities": ["Ijebu-Ode", "Ogbere", "Ejinrin", "Ojowo"],
            },
        },
        "Kano": {
            "Kano Municipal": {
                "street_names": [
                    "Bello Road",
                    "Ibrahim Taiwo Road",
                    "Kofar Nassarawa Road",
                    "Bank Road",
                    "Kofar Wambai Road",
                    "Sarkin Yaki Road",
                ],
                "cities": ["Kano", "Dala", "Nasarawa", "Gwale"],
            },
            "Fagge": {
                "street_names": [
                    "Sabo Bakin Zuwo Road",
                    "Janguza Road",
                    "Yankaba Road",
                    "Daurawa Road",
                    "Yakasai Road",
                    "Babban Daki Road",
                ],
                "cities": ["Fagge", "Yankaba", "Bakin Zuwo", "Daurawa"],
            },
            "Gwale": {
                "street_names": [
                    "Gidan Murtala Road",
                    "Rijiyar Zaki Road",
                    "Filing Dabo Road",
                    "Giginyu Road",
                    "Wudil Road",
                    "Rijiyar Lemo Road",
                ],
                "cities": ["Gwale", "Rijiyar Zaki", "Giginyu", "Fagge"],
            },
            "Nassarawa": {
                "street_names": [
                    "Bataiya Road",
                    "Katsina Road",
                    "Rijiyar Zaki Road",
                    "Barnawa Road",
                    "Yalwa Road",
                    "Gwammaja Road",
                ],
                "cities": ["Nassarawa", "Kofar Wambai", "Rijiyar Lemo", "Gidan Dabo"],
            },
        },
        "Rivers": {
            "Port Harcourt": {
                "street_names": [
                    "Abacha Road",
                    "Aggrey Road",
                    "Stadium Road",
                    "Aba Road",
                    "Trans-Amadi Road",
                    "Rumuola Road",
                ],
                "cities": ["Port Harcourt", "D-line", "Trans-Amadi", "Rumuola"],
            },
            "Obio/Akpor": {
                "street_names": [
                    "Nkpolu Road",
                    "Elelenwo Road",
                    "Rumuokwurusi Road",
                    "Slaughter Road",
                    "Eneka Road",
                    "Choba Road",
                ],
                "cities": ["Rumuokwurusi", "Rumuepirikom", "Rumukwurusi", "Rumuokoro"],
            },
            "Ikwerre": {
                "street_names": [
                    "Wimpey Road",
                    "Nkpolu Road",
                    "Rumuigbo Road",
                    "Igwuruta Road",
                    "Ozuoba Road",
                    "Isiokpo Road",
                ],
                "cities": ["Rumuigbo", "Nkpolu", "Rumueme", "Ozuoba"],
            },
            "Eleme": {
                "street_names": [
                    "Ogale Road",
                    "Ebubu Road",
                    "Onne Road",
                    "Aleto Road",
                    "Agbonchia Road",
                    "Oyigbo Road",
                ],
                "cities": ["Onne", "Ebubu", "Aleto", "Eteo"],
            },
        },
        "Enugu": {
            "Enugu East": {
                "street_names": [
                    "Independence Layout",
                    "Rangers Avenue",
                    "Abakpa Nike Road",
                    "Ogui Road",
                    "New Haven Road",
                    "Trans-Ekulu Road",
                ],
                "cities": [
                    "Enugu",
                    "Independence Layout",
                    "Trans-Ekulu",
                    "Abakpa Nike",
                ],
            },
            "Nsukka": {
                "street_names": [
                    "University Road",
                    "Alor Uno Road",
                    "Ibagwa Road",
                    "Odenigwe Road",
                    "Owerre Ezukala Road",
                    "Akpugo Road",
                ],
                "cities": ["Nsukka", "Odenigwe", "Ibagwa", "Owerre Ezukala"],
            },
            "Enugu North": {
                "street_names": [
                    "Zik Avenue",
                    "Ogui Road",
                    "Rangers Avenue",
                    "Coal Camp Road",
                    "Uwani Road",
                    "Golf Estate Road",
                ],
                "cities": ["Enugu", "Uwani", "Rangers", "New Haven"],
            },
            "Enugu South": {
                "street_names": [
                    "Akpugo Road",
                    "Udi Road",
                    "Awgu Road",
                    "Agbani Road",
                    "Eke Road",
                    "Opi Road",
                ],
                "cities": ["Enugu", "Agbani", "Akpugo", "Udi"],
            },
        },
        "Delta": {
            "Warri": {
                "street_names": [
                    "Effurun-Sapele Road",
                    "Ajamimogha Road",
                    "Airport Road",
                    "Okumagba Avenue",
                    "Jakpa Road",
                    "Deco Road",
                ],
                "cities": ["Warri", "Effurun", "Ekpan", "Ugbuwangue"],
            },
            "Ughelli": {
                "street_names": [
                    "Ughelli-Patani Road",
                    "Market Road",
                    "Isoko Road",
                    "Agbarha Road",
                    "Oteri Road",
                    "Iwhrekan Road",
                ],
                "cities": ["Ughelli", "Oteri", "Agbarha-Otor", "Ovwian"],
            },
            "Asaba": {
                "street_names": [
                    "Nnebisi Road",
                    "Anwai Road",
                    "Okpanam Road",
                    "Dennis Osadebe Way",
                    "Summit Road",
                    "Mariam Babangida Way",
                ],
                "cities": ["Asaba", "Okpanam", "Illah", "Ibusa"],
            },
            "Sapele": {
                "street_names": [
                    "Warri-Sapele Road",
                    "New Ogorode Road",
                    "Amukpe Road",
                    "Market Road",
                    "Deco Road",
                    "Okirigbobor Road",
                ],
                "cities": ["Sapele", "Amukpe", "Elume", "Ogorode"],
            },
        },
    }

    state = random.choice(list(states.keys()))
    lgas = states[state]
    city = random.choice(list(lgas.keys()))
    lga = random.choice(list(lgas))  # Convert lgas.keys() to list

    # Get street names for the selected city
    street_names = lgas[city]["street_names"]
    street_name = random.choice(street_names)

    # Generate a random street number (between 1 and 100)
    street_number = random.randint(1, 100)

    # Use the selected street name, city, LGA, and state to create an address
    address = f"{street_number} {street_name} Str., {city}, {lga} LGA, {state} State"
    return address


class bio:
    def __init__(self) -> None:
        pass

    def generate_name(self):
        first_name = [
            "Abiola",
            "Adamma",
            "Adeola",
            "Ahmed",
            "Aisha",
            "Amara",
            "Anayo",
            "Anita",
            "Ayodele",
            "Bisi",
            "Chiamaka",
            "Chibuzo",
            "Chidinma",
            "Chioma",
            "Chukwudi",
            "Damilola",
            "Ebuka",
            "Emeka",
            "Ezinne",
            "Folarin",
            "Funke",
            "Ganiyu",
            "Halima",
            "Hassan",
            "Ifeanyi",
            "Ikechukwu",
            "Immanuel",
            "Isaiah",
            "Jide",
            "Kafayat",
            "Kemi",
            "Khadija",
            "Lola",
            "Musa",
            "Nkechi",
            "Nnamdi",
            "Nneka",
            "Obinna",
            "Ogechi",
            "Olajide",
            "Olufemi",
            "Oluwakemi",
            "Omolara",
            "Onyeka",
            "Osagie",
            "Patience",
            "Rasheed",
            "Rukayat",
            "Sadiq",
            "Sandra",
            "Seyi",
            "Suleiman",
            "Taiwo",
            "Temitope",
            "Tunde",
            "Uche",
            "Umar",
            "Yakubu",
            "Yusuf",
            "Zainab",
            "Abiola",
            "Adamma",
            "Adeola",
            "Ahmed",
            "Aisha",
            "Amara",
            "Anayo",
            "Anita",
            "Ayodele",
            "Bisi",
            "Chiamaka",
            "Chibuzo",
            "Chidinma",
            "Chioma",
            "Chukwudi",
            "Damilola",
            "Ebuka",
            "Emeka",
            "Olajide",
            "Olufemi",
            "Oluwakemi",
            "Omolara",
            "Ahmed",
            "Vande",
            "Obinna",
            "Dayo",
            "Obinna",
            "Ada",
            "Ahmed",
            "Aisha",
            "Amaka",
            "Bola",
            "Chidi",
            "Chioma",
            "Chukwudi",
            "Daniel",
            "Ebere",
            "Emeka",
            "Ese",
            "Femi",
            "Funke",
            "Gabriel",
            "Halima",
            "Hassan",
            "Ifeanyi",
            "Ini",
            "Jamil",
            "Jumoke",
            "Kabiru",
            "Kemi",
            "Lekan",
            "Maimuna",
            "Mariam",
            "Mohammed",
            "Ngozi",
            "Nkechi",
            "Nnamdi",
            "Obinna",
            "Oluchi",
            "Oluwafemi",
            "Onyinye",
            "Peter",
            "Rachael",
            "Safiya",
            "Suleiman",
            "Temitope",
            "Uche",
            "Umaru",
            "Victoria",
            "Yemi",
            "Yusuf",
            "Zahra",
            "Zainab",
            "Chukwuemeka",
            "Ngozi",
            "Ibrahim",
            "Adaeze",
            "Ifeanyi",

            "Jibril",
            "Johnson",
            "Kuti",
            "Lawal",
            "Maduka",
            "Mahmud",
            "Mohammed",
            "Musa",
            "Nwachukwu",
            "Nwosu",
            "Obi",
            "Odeyemi",
            "Odumegwu",
            "Ogundipe",
            "Oguntade",
            "Okeke",
            "Okonkwo",
            "Oladipo",
            "Olajide",
            "Adekunle",
            "Onwuka",
            "Osagie",
            "Okafor",
            "Adebayo",
            "Adegoke",
            "Eze",
            "Ogundele",
            "Okoro",
            "Nwosu",
            "Okafor",
            "Egwu",
            "Oladipo",
            "Okeke",
            "Nnamdi",
            "Ibe",
            "Adewale",
            "Abdul",
            "Okonkwo",
            "Aliyu",
            "Onyeka",
            "Okoli",
            "Chukwu",
            "Ahmed",
            "Eze",
            "Adamu",
            "Akintola",
            "Ogunbiyi",
            "Iwu",
            "Adeyemi",
            "Obi",
            "Musa",
            "Nwachukwu",
            "Usman",
            "Ude",
            "Lawal",
            "Okafor",
            "Mohammed",
            "Eze",
            "Ibrahim",
            "Anyanwu",
            "Olamide",
            "Ogundele",
            "Akinwale",
            "Balogun",
            "Okonkwo",
            "Onyeka",
            "Sani",
            "Eze",
            "Mohammed",
            "Okafor",
            "Ibrahim",
            "Nwachukwu",
            "Ahmed",
            "Nwosu",
            "Hassan",
            "Onuoha",
            "Lawal",
            "Eze",
            "Suleiman",
            "Okoye",
            "Eze",
            "Nwachukwu",
            "Okafor",
            "Nwosu",
            "Abdullahi",
        ]

        firstname = random.choice(first_name)
        lastname = random.choice(last_name)

        name = f"{firstname} {lastname}"

        return name

    def generate_email(self):
        # name = self.generate_name()
        name_2 = name.lower().replace(" ", "")
        # Remove spaces in the generated name

        domain = random.choice(["@yahoo.com", "@gmail.com"])
        email = f"{name_2}{domain}"
        return email


class bionum:
    def __init__(self) -> None:
        pass

    def generate_names(self):
        first_name = [
            "Abiola",
            "Adamma",
            "Adeola",
            "Ahmed",
            "Aisha",
            "Amara",
            "Anayo",
            "Anita",
            "Ayodele",
            "Bisi",
            "Chiamaka",
            "Chibuzo",
            "Chidinma",
            "Chioma",
            "Chukwudi",
            "Damilola",
            "Ebuka",
            "Emeka",
            "Ezinne",
            "Folarin",
            "Funke",
            "Ganiyu",
            "Halima",
            "Hassan",
            "Ifeanyi",
            "Ikechukwu",
            "Immanuel",
            "Isaiah",
            "Jide",
            "Kafayat",
            "Kemi",
            "Khadija",
            "Lola",
            "Musa",
            "Nkechi",
            "Nnamdi",
            "Nneka",
            "Obinna",
            "Ogechi",
            "Olajide",
            "Olufemi",
            "Oluwakemi",
            "Omolara",
            "Onyeka",
            "Osagie",
            "Patience",
            "Rasheed",
            "Rukayat",
            "Sadiq",
            "Sandra",
            "Seyi",
            "Suleiman",
            "Taiwo",
            "Temitope",
            "Tunde",
            "Uche",
            "Umar",
            "Yakubu",
            "Yusuf",
            "Zainab",
            "Abiola",
            "Adamma",
            "Adeola",
            "Ahmed",
            "Aisha",
            "Amara",
            "Anayo",
            "Anita",
            "Ayodele",
            "Bisi",
            "Chiamaka",
            "Chibuzo",
            "Chidinma",
            "Chioma",
            "Chukwudi",
            "Damilola",
            "Ebuka",
            "Emeka",
            "Olajide",
            "Olufemi",
            "Oluwakemi",
            "Omolara",
            "Ahmed",
            "Vande",
            "Obinna",
            "Dayo",
            "Obinna",
            "Ada",
            "Ahmed",
            "Aisha",

            "Jibril",
            "Johnson",
            "Kuti",
            "Lawal",
            "Madu",
            "Mohammed",
            "Mustapha",
            "Nwachukwu",
            "Obi",
            "Obioma",
            "Odeyemi",
            "Ogbu",
            "Ogunjimi",
            "Kolapo",
            "Lawal",
            "Elijaj",
            "Julius",
            "Ehinmoro",
            "Jude",
            "Abubakar",
            "Adewale",
            "Afolabi",
            "Ajayi",
            "Akintola",
            "Alabi",
            "Aliyu",
            "Aminu",
            "Azikiwe",
            "Babatunde",
            "Balogun",
            "Bello",
            "Chukwu",
            "Dauda",
            "Egbu",
            "Eke",
            "Ekwueme",
            "Emeka",
            "Fashola",
            "Gbenga",
            "Ibrahim",
            "Idris",
            "Igbinedion",
            "Iheanacho",
            "Ikenwa",
            "Iroegbu",
            "Ismail",
            "Jibril",
            "Johnson",
            "Kuti",
            "Lawal",
            "Maduka",
            "Mahmud",
            "Mohammed",
            "Musa",
            "Nwachukwu",
            "Nwosu",
            "Obi",
            "Odeyemi",
            "Odumegwu",
            "Ogundipe",
            "Oguntade",
            "Okeke",
            "Okonkwo",
            "Oladipo",
            "Olajide",
            "Adekunle",
            "Onwuka",
            "Osagie",
            "Okafor",
            "Adebayo",
            "Adegoke",
            "Eze",
            "Ogundele",
            "Okoro",
            "Nwosu",
            "Okafor",
            "Egwu",
            "Oladipo",
            "Okeke",
            "Nnamdi",
            "Ibe",
            "Adewale",
            "Abdul",
            "Okonkwo",
            "Aliyu",
            "Onyeka",
            "Okoli",
            "Chukwu",
            "Ahmed",
            "Eze",
            "Adamu",
            "Akintola",
            "Ogunbiyi",
            "Iwu",
            "Adeyemi",
            "Obi",
            "Musa",
            "Nwachukwu",
            "Usman",
            "Ude",
            "Lawal",
            "Okafor",
            "Mohammed",
            "Eze",
            "Ibrahim",
            "Anyanwu",
            "Olamide",
            "Ogundele",
            "Akinwale",
            "Balogun",
            "Okonkwo",
            "Onyeka",
            "Sani",
            "Eze",
            "Mohammed",
            "Okafor",
            "Ibrahim",
            "Nwachukwu",
            "Ahmed",
            "Nwosu",
            "Hassan",
            "Onuoha",
            "Lawal",
            "Eze",
            "Suleiman",
            "Okoye",
            "Eze",
            "Nwachukwu",
            "Okafor",
            "Nwosu",
            "Abdullahi",
        ]

        firstname = random.choice(first_name)
        lastname = random.choice(last_name)

        names = f"{firstname} {lastname}"

        return names

    def generate_emails(self):
        names = self.generate_names()
        name_3 = names.lower().replace(" ", "")
        # Remove spaces in the generated name

        domain = random.choice(["@yahoo.com", "@gmail.com"])
        email = f"{name_3}{domain}"
        return email


bio_data_2 = bionum()
bio_data = bio()
min_year = 1963
max_year = 2003

min_year_gt = 1950
max_year_gt = 1990

start_date = datetime.date(min_year, 1, 1)
end_date = datetime.date(max_year, 12, 31)


start_date_gt = datetime.date(min_year_gt, 1, 1)
end_date_gt = datetime.date(max_year_gt, 12, 31)


# Open a CSV file for writing
with open(
    "C:/Users/Todays Soutions/Documents/Data_Science/DATA/loannewdata.csv",
    "w",
    newline="",
) as file:
    writer = csv.writer(file)
    # Write header row

    writer.writerow(
        [
            "customer_id",
            "name",
            "phone_number",
            "email_address",
            "date_of_birth",
            "address",
            "national_identity_number",
            "employment",
            "income_per_month",
            "loan_type",
            "applicant_job_role",
            "repayment_type",
            "collateral_type",
            "collateral_value",
            "guarantor_name",
            "guarantor_phone_number",
            "guarantor_email",
            "guarantor_dob",
            "guarantor_address",
            "guarantor_social_security_number",
            "guarantor_relationship",
            "guarantor_employment",
            "guarantor_other_sources_of_income",
            "guarantor_income_per_month",
            "loan_amount",
            "loan_default",
        ]
    )

    # Generate 200,000 rows of data
    for _ in range(700):
        customer_id = "LA-" + str(fake.random_number(digits=6)).zfill(6)
        name = bio_data.generate_name()
        phone_number = (
            fake.random_element(["080", "070", "081", "090", "091"])
            + "-"
            + fake.numerify("####")
            + "-"
            + fake.numerify("####")
        )

        email = bio_data.generate_email()

        date_of_birth = fake.date_between(start_date=start_date, end_date=end_date)

        address = generate_random_address()
        national_indentity_number = fake.random_number(digits=11)
        employment = fake.random_element(
            ["FullTime", "PartTime", "Self-Employed", "Contract"]
        )
        income_per_month = fake.random_int(min=50000, max=500000)
        loan_type = fake.random_element(
            ["Housing Loan", "Student Loan", "Agricultural Loan", "Business Loan"]
        )
        Applicants_Job_Role = fake.random_element(
            [
                "Accountant (Accounting and Finance)",
                "Financial Analyst (Accounting and Finance)",
                "Auditor (Accounting and Finance)",
                "Tax Specialist (Accounting and Finance)",
                "Financial Manager (Accounting and Finance)",
                "Marketing Manager (Marketing and Advertising)",
                "Digital Marketer (Marketing and Advertising)",
                "Brand Manager (Marketing and Advertising)",
                "Advertising Executive (Marketing and Advertising)",
                "Market Research Analyst (Marketing and Advertising)",
                "Software Developer (Information Technology",
                "Network Administrator (Information Technology)",
                "Data Scientist (Information Technology)",
                "Cybersecurity Analyst (Information Technology)",
                "IT Project Manager (Information Technology)",
                "Doctor (Healthcare)",
                "Nurse (Healthcare)",
                "Medical Assistant (Healthcare)",
                "Pharmacist (Healthcare)",
                "Physical Therapist (Healthcare)",
                "Teacher (Education and Training)",
                "Professor (Education and Training)",
                "Instructional Designer (Education and Training)",
                "Training Specialist (Education and Training)",
                "Education Consultant (Education and Training)",
                "Sales Representative (Sales and Customer Service)",
                "Account Manager (Sales and Customer Service)",
                "Customer Service Representative (Sales and Customer Service)",
                "Sales Manager (Sales and Customer Service)",
                "Retail Associate (Sales and Customer Service)",
                "Mechanical Engineer (Engineering)",
                "Electrical Engineer (Engineering)",
                "Civil Engineer (Engineering)",
                "Quality Control Inspector (Engineering)",
                "HR Manager (Human Resources)",
                "Recruitment Specialist (Human Resources)",
                "Training and Development Manager (Human Resources)",
                "Compensation and Benefits Analyst (Human Resources)",
                "Project Manager (Project Management)",
                "Agile Coach (Project Management)",
                "Scrum Master (Project Management)",
                "Program Manager (Project Management)",
                "Operations Manager (Operations and Logistics)",
                "Supply Chain Analyst (Operations and Logistics)",
                "Warehouse Supervisor (Operations and Logistics)",
                "Logistics Coordinator (Operations and Logistics)",
                "Lawyer (Legal)",
                "Paralegal (Legal)",
                "Judge (Legal)",
                "Legal Counsel (Legal)",
            ]
        )

        repayment_type = fake.random_element(
            [
                "Principal & Interest",
            ]
        )

        credit_score = fake.random_number(digits=3)
        collateral_type = fake.random_element(["Business Equipment", "Real Estate"])
        collateral_value = fake.random_int(min=100000, max=10000000)
        guarantor_name = bio_data_2.generate_names()
        guarantor_phone_number = (
            fake.random_element(["080", "070", "081", "090"])
            + "-"
            + fake.numerify("####")
            + "-"
            + fake.numerify("####")
        )

        guarantor_email = bio_data_2.generate_emails()
        guarantor_dob = fake.date_between(
            start_date=start_date_gt, end_date=end_date_gt
        )
        guarantor_address = generate_random_address()
        guarantor_ssn = fake.ssn()
        guarantor_relationship = fake.random_element(
            ["Parent", "Sister", "Brother", "Spouse", "Friend", "Employer"]
        )
        guarantor_employment = fake.random_element(
            ["FullTime", "PartTime", "Retiree", "Contract", "Business Owner"]
        )

        guarantor_other_sources_income = fake.random_element(
            [
                "Rental Income",
                "Investment Income",
                "Freelancing",
                "Business Profits",
                "Royalties",
                "Agriculture and Farming",
                "Rental of Assets",
            ]
        )

        guarantor_income_per_month = fake.random_int(min=200000, max=1000000)
        loan_amount = fake.random_int(min=10000, max=1000000)

        loan_default = fake.random_element(["Yes", "No"])

        # Write the data to the CSV file
        writer.writerow(
            [
                customer_id,
                name,
                phone_number,
                email,
                date_of_birth,
                address,
                national_indentity_number,
                employment,
                income_per_month,
                loan_type,
                applicants_job_role_sector,
                repayment_type,
                collateral_type,
                collateral_value,
                guarantor_name,
                guarantor_phone_number,
                guarantor_email,
                guarantor_dob,
                guarantor_address,
                guarantor_ssn,
                guarantor_relationship,
                guarantor_employment,
                guarantor_other_sources_income,
                guarantor_income_per_month,
                loan_amount,
                loan_default,
            ]
        )

# %%
df = pd.read_csv("C:/Users/Todays Soutions/Documents/Data_Science/DATA/loannewdata.csv")
df.head()
# Out:
#   customer_id               name   phone_number               email_address  \
# 0   LA-130043  Chukwudi Ehinmoro  080-4943-0873  chukwudiehinmoro@gmail.com
# 1   LA-349394     Anayo Mohammed  081-8113-3936     anayomohammed@yahoo.com
# 2   LA-005172  Adanna Igbinedion  081-6367-8834  adannaigbinedion@gmail.com
# 3   LA-381531       Emeka Hassan  091-2347-9948       emekahassan@gmail.com
# 4   LA-817637      Ahmed Adegoke  070-5392-9632      ahmedadegoke@gmail.com
#
#   date_of_birth  \
# 0    1967-12-16
# 1    1987-07-31
# 2    1988-01-02
# 3    1969-07-04
# 4    1972-10-06
#
#                                                           address  \
# 0        52 Yalwa Road Str., Nassarawa, Nassarawa LGA, Kano State
# 1  94 Ughelli-Patani Road Str., Ughelli, Ughelli LGA, Delta State
# 2            52 Yalwa Road Str., Nassarawa, Gwale LGA, Kano State
# 3        46 Lalubu Road Str., Abeokuta, Ijebu-Ode LGA, Ogun State
# 4           87 Nkpolu Road Str., Ikwerre, Eleme LGA, Rivers State
#
# ...

# %%
fake = Faker()

phone_number = fake.numerify("080-####-####")
print(phone_number)

# %%
Borrower's Information

Personal and contact information
Name
Phone Number
Email Address
Date of Birth
Address
National Identity Number
Employment [Dropdown(FullTime, PartTime, Self Employed, Contract)]
Income per month

Loan Information
Loan Type [Dropdown(Business Loan, Student Loan, Agricultural Loan and Housing Loan)]
Repayment Term [Dropdown(Interest only, Principal & Interest, Capitalized Interest, Housing Loan, Others)]
Upload Credit report
Update Credit score

Collateral Information
Collateral Type [Dropdown(Real Estate, Business Equipment)]
Collateral Value

Guarantor's Information
Name
Phone Number
Email
Date of Birth
Address
Social Security Number
Relationship
Employment
Other sources of income
Income per month

# %%
address = generate_randomy_address()
print(address)

# %%
import os
import csv

# Delete the existing CSV file if it exists
file_path = "C:/Users/Todays Soutions/Documents/Data_Science/DATA/loan_newdata.csv"
if os.path.exists(file_path):
    os.remove(file_path)
    print("Existing CSV file deleted.")

# Code to create and correct the CSV file
# ...
# Include the code from the previous example to generate the corrected CSV file

print("CSV file corrected successfully.")

# %%
with open(
    "C:/Users/Todays Soutions/Documents/Data_Science/DATA/loandash.csv",
    "w",
    newline="",
) as file:
    writer = csv.writer(file)
    # Write header row

    writer.writerow(
        [
            "customer_id",
            "loans_refunded",
            "loans_declined",
            "pending_loans",
            "loans_generated",
        ]
    )
    for _ in range(700):

        customer_id = "LA" + str(fake.random_number(digits=6)).zfill(6)
        loans_refunded = random.randint(10000, 500000)
        loans_declined = random.randint(50000, 250000)
        pending_loans = random.randint(5000, 100000)
        loans_generated = loans_refunded + loans_declined + pending_loans

        writer.writerow(
            [loans_refunded, loans_declined, pending_loans, loans_generated]
        )

# %%
import csv
import random
fake.seed(123)
          

with open(
    "C:/Users/Todays Soutions/Documents/Data_Science/DATA/loandash.csv", "w", newline=""
) as file:
    writer = csv.writer(file)
    writer.writerow(
        [
            "customer_id",
            "loans_refunded",
            "loans_declined",
            "pending_loans",
            "loans_generated",
        ]
    )
    for _ in range(700):
        customer_id = "LA" + str(fake.random_number(digits=6)).zfill(6)
        loans_refunded = random.randint(10000, 500000)
        loans_declined = random.randint(50000, 250000)
        pending_loans = random.randint(5000, 100000)
        loans_generated = loans_refunded + loans_declined + pending_loans

        writer.writerow(
            [
                customer_id,
                loans_refunded,
                loans_declined,
                pending_loans,
                loans_generated,
            ]
        )

# %%
df = pd.read_csv("C:/Users/Todays Soutions/Documents/Data_Science/DATA/loandash.csv")
df.head()
# Out:
#   customer_id  loans_refunded  loans_declined  pending_loans  loans_generated
# 0    LA146877          191828           86177          56996           335001
# 1    LA338595          275798          201289          15998           493085
# 2    LA037618          119046          227607          15163           361816
# 3    LA664084          313024           85239          26967           425230
# 4    LA548794          327238          177244          94140           598622

# %%
df_loans_generated = df["loans_generated"].sum()
df_loans_generated
# Out:
# 319211724

# %%
df_loans_refunded = df["loans_refunded"].sum()
df_loans_refunded
# Out:
# 175605927

# %%
df_loans_declined = df["loans_declined"].sum()
df_loans_declined
# Out:
# 106096980

# %%
df_pending_loans = df["pending_loans"].sum()
df_pending_loans
# Out:
# 37508817

# %%
# # Make a POST request to the API endpoint
# response = requests.post('https://api.example.com/data', json=data)

# # Check the response status code
# if response.status_code == 200:
#     print('Data sent successfully')
# else:
#     print('Failed to send data')
